# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# # Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 794

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | bulgan
# Processing Record 5 of Set 1 | yulara
# Processing Record 6 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | ulladulla
# Processing Record 11 of Set 1 | komsomolskiy
# Processing Record 12 of Set 1 | tumpat
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | dunedin
# Processing Record 15 of Set 1 | beian
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | leh
# Processing Record 19 of Set 1 | severo-kurilsk
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | vysokogornyy
# Processing Record 22 of Set 1 | whitehorse
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | dingle
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 1 | najran
# Processing Record 28 of Set 1 | saint-pacome
# City not found. Skipping...
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | omutninsk
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | epalinges
# Processing Record 33 of Set 1 | victoria
# Processing Record 34 of Set 1 | dekar
# Processing Record 35 of Set 1 | tagusao
# Processing Record 36 of Set 1 | stokmarknes
# Processing Record 37 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 1 | emerald
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | bambous virieux
# Processing Record 43 of Set 1 | san quintin
# Processing Record 44 of Set 1 | san ignacio
# Processing Record 45 of Set 1 | sao filipe
# Processing Record 46 of Set 1 | cherskiy
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | tasiilaq
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | thilogne
# City not found. Skipping...
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | jacareacanga
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | shieli
# Processing Record 5 of Set 2 | hami
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | kaitong
# Processing Record 8 of Set 2 | katherine
# Processing Record 9 of Set 2 | mount isa
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | osa
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | morgan city
# Processing Record 14 of Set 2 | planadas
# Processing Record 15 of Set 2 | gravdal
# Processing Record 16 of Set 2 | nantucket
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | udon thani
# Processing Record 19 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | alta floresta
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | el carmen
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | klaksvik
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | cam pha
# City not found. Skipping...
# Processing Record 29 of Set 2 | katsuura
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | el guantillo
# Processing Record 32 of Set 2 | sfantu gheorghe
# Processing Record 33 of Set 2 | cabo san lucas
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | pacific grove
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | hamilton
# Processing Record 39 of Set 2 | ladario
# Processing Record 40 of Set 2 | vardo
# Processing Record 41 of Set 2 | wagar
# Processing Record 42 of Set 2 | kiunga
# Processing Record 43 of Set 2 | cidreira
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | faanui
# Processing Record 46 of Set 2 | mama
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | san patricio
# Processing Record 50 of Set 2 | seoul
# Processing Record 1 of Set 3 | rawson
# Processing Record 2 of Set 3 | esperance
# Processing Record 3 of Set 3 | portland
# Processing Record 4 of Set 3 | beboto
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | bethel
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | lhokseumawe
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | tiznit
# Processing Record 11 of Set 3 | tocopilla
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | narsaq
# Processing Record 14 of Set 3 | aklavik
# Processing Record 15 of Set 3 | kamenka
# Processing Record 16 of Set 3 | saint anthony
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | sydney
# Processing Record 19 of Set 3 | isangel
# Processing Record 20 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 3 | kostek
# Processing Record 22 of Set 3 | burnie
# Processing Record 23 of Set 3 | novochernorechenskiy
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | uige
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | koutiala
# Processing Record 28 of Set 3 | skovde
# City not found. Skipping...
# Processing Record 29 of Set 3 | juneau
# Processing Record 30 of Set 3 | bluff
# Processing Record 31 of Set 3 | eldorado
# Processing Record 32 of Set 3 | vestmanna
# Processing Record 33 of Set 3 | lengshuitan
# Processing Record 34 of Set 3 | kui buri
# Processing Record 35 of Set 3 | meadow lake
# Processing Record 36 of Set 3 | sinop
# Processing Record 37 of Set 3 | saint-pierre
# Processing Record 38 of Set 3 | ixtapa
# Processing Record 39 of Set 3 | ancud
# Processing Record 40 of Set 3 | puerto leguizamo
# Processing Record 41 of Set 3 | port hedland
# Processing Record 42 of Set 3 | vestmannaeyjar
# Processing Record 43 of Set 3 | mareeba
# Processing Record 44 of Set 3 | berlevag
# Processing Record 45 of Set 3 | devils lake
# Processing Record 46 of Set 3 | touros
# Processing Record 47 of Set 3 | ucluelet
# Processing Record 48 of Set 3 | leningradskiy
# Processing Record 49 of Set 3 | castro
# Processing Record 50 of Set 3 | keuruu
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | praia
# Processing Record 3 of Set 4 | floro
# Processing Record 4 of Set 4 | leshukonskoye
# Processing Record 5 of Set 4 | shahkot
# Processing Record 6 of Set 4 | vila franca do campo
# Processing Record 7 of Set 4 | nouadhibou
# Processing Record 8 of Set 4 | ca mau
# Processing Record 9 of Set 4 | egvekinot
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | boyuibe
# Processing Record 12 of Set 4 | llanes
# Processing Record 13 of Set 4 | portree
# Processing Record 14 of Set 4 | hilo
# Processing Record 15 of Set 4 | muli
# Processing Record 16 of Set 4 | hofn
# Processing Record 17 of Set 4 | tuatapere
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | richards bay
# Processing Record 20 of Set 4 | antofagasta
# Processing Record 21 of Set 4 | ruston
# Processing Record 22 of Set 4 | safranbolu
# Processing Record 23 of Set 4 | fort nelson
# Processing Record 24 of Set 4 | caravelas
# Processing Record 25 of Set 4 | tumut
# Processing Record 26 of Set 4 | nagarote
# Processing Record 27 of Set 4 | ponta delgada
# Processing Record 28 of Set 4 | half moon bay
# Processing Record 29 of Set 4 | tahta
# Processing Record 30 of Set 4 | chapais
# Processing Record 31 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 32 of Set 4 | show low
# Processing Record 33 of Set 4 | muros
# Processing Record 34 of Set 4 | linhares
# Processing Record 35 of Set 4 | chudniv
# Processing Record 36 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 4 | ahipara
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | sao gabriel da cachoeira
# Processing Record 40 of Set 4 | nome
# Processing Record 41 of Set 4 | makakilo city
# Processing Record 42 of Set 4 | ivrea
# Processing Record 43 of Set 4 | payson
# Processing Record 44 of Set 4 | dera din panah
# City not found. Skipping...
# Processing Record 45 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 4 | knysna
# Processing Record 47 of Set 4 | shingu
# Processing Record 48 of Set 4 | yellowknife
# Processing Record 49 of Set 4 | ajdabiya
# Processing Record 50 of Set 4 | yuncheng
# Processing Record 1 of Set 5 | astipalaia
# City not found. Skipping...
# Processing Record 2 of Set 5 | waingapu
# Processing Record 3 of Set 5 | prieska
# Processing Record 4 of Set 5 | leland
# Processing Record 5 of Set 5 | sunland park
# Processing Record 6 of Set 5 | bolshoye murashkino
# Processing Record 7 of Set 5 | dickinson
# Processing Record 8 of Set 5 | galle
# Processing Record 9 of Set 5 | port elizabeth
# Processing Record 10 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 5 | jutai
# Processing Record 13 of Set 5 | banda aceh
# Processing Record 14 of Set 5 | bajil
# Processing Record 15 of Set 5 | livramento
# Processing Record 16 of Set 5 | east london
# Processing Record 17 of Set 5 | clyde river
# Processing Record 18 of Set 5 | general roca
# Processing Record 19 of Set 5 | hualmay
# Processing Record 20 of Set 5 | manta
# Processing Record 21 of Set 5 | axim
# Processing Record 22 of Set 5 | sitka
# Processing Record 23 of Set 5 | inyonga
# Processing Record 24 of Set 5 | stornoway
# Processing Record 25 of Set 5 | asau
# Processing Record 26 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 5 | ponta do sol
# Processing Record 28 of Set 5 | chernyshevskiy
# Processing Record 29 of Set 5 | adrar
# Processing Record 30 of Set 5 | vila velha
# Processing Record 31 of Set 5 | asyut
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | hargeysa
# Processing Record 34 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 5 | rio grande
# Processing Record 36 of Set 5 | kalmunai
# Processing Record 37 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 5 | goderich
# Processing Record 39 of Set 5 | sangar
# Processing Record 40 of Set 5 | namibe
# Processing Record 41 of Set 5 | banjar
# Processing Record 42 of Set 5 | mumford
# Processing Record 43 of Set 5 | aiken
# Processing Record 44 of Set 5 | shimoda
# Processing Record 45 of Set 5 | girona
# Processing Record 46 of Set 5 | ruidoso
# Processing Record 47 of Set 5 | sao felix do xingu
# Processing Record 48 of Set 5 | qaqortoq
# Processing Record 49 of Set 5 | puerto baquerizo moreno
# Processing Record 50 of Set 5 | turtas
# Processing Record 1 of Set 6 | turukhansk
# Processing Record 2 of Set 6 | arlit
# Processing Record 3 of Set 6 | zyryanka
# Processing Record 4 of Set 6 | norman wells
# Processing Record 5 of Set 6 | verkhoyansk
# Processing Record 6 of Set 6 | senovo
# Processing Record 7 of Set 6 | namatanai
# Processing Record 8 of Set 6 | ostrovnoy
# Processing Record 9 of Set 6 | sistranda
# Processing Record 10 of Set 6 | torbay
# Processing Record 11 of Set 6 | lavrentiya
# Processing Record 12 of Set 6 | hithadhoo
# Processing Record 13 of Set 6 | rapar
# Processing Record 14 of Set 6 | coquimbo
# Processing Record 15 of Set 6 | constantine
# Processing Record 16 of Set 6 | hudson bay
# Processing Record 17 of Set 6 | nata
# Processing Record 18 of Set 6 | kuytun
# Processing Record 19 of Set 6 | koson
# Processing Record 20 of Set 6 | naze
# Processing Record 21 of Set 6 | margate
# Processing Record 22 of Set 6 | nemuro
# Processing Record 23 of Set 6 | praya
# Processing Record 24 of Set 6 | havoysund
# Processing Record 25 of Set 6 | luganville
# Processing Record 26 of Set 6 | minab
# Processing Record 27 of Set 6 | borama
# City not found. Skipping...
# Processing Record 28 of Set 6 | chalinze
# Processing Record 29 of Set 6 | pipri
# Processing Record 30 of Set 6 | redmond
# Processing Record 31 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 6 | kalaleh
# Processing Record 33 of Set 6 | moa
# Processing Record 34 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 6 | nanortalik
# Processing Record 36 of Set 6 | salta
# Processing Record 37 of Set 6 | strezhevoy
# Processing Record 38 of Set 6 | raudeberg
# Processing Record 39 of Set 6 | te anau
# Processing Record 40 of Set 6 | ahuimanu
# Processing Record 41 of Set 6 | blagoyevo
# Processing Record 42 of Set 6 | mecca
# Processing Record 43 of Set 6 | merauke
# Processing Record 44 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 6 | port hardy
# Processing Record 46 of Set 6 | oda
# Processing Record 47 of Set 6 | mangaratiba
# Processing Record 48 of Set 6 | roald
# Processing Record 49 of Set 6 | zhigansk
# Processing Record 50 of Set 6 | vyazma
# Processing Record 1 of Set 7 | gornopravdinsk
# Processing Record 2 of Set 7 | kaniama
# Processing Record 3 of Set 7 | bonthe
# Processing Record 4 of Set 7 | santiago de chuco
# Processing Record 5 of Set 7 | saldanha
# Processing Record 6 of Set 7 | honningsvag
# Processing Record 7 of Set 7 | suez
# Processing Record 8 of Set 7 | brae
# Processing Record 9 of Set 7 | longhua
# Processing Record 10 of Set 7 | morondava
# Processing Record 11 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 7 | quang ngai
# Processing Record 13 of Set 7 | montepulciano
# Processing Record 14 of Set 7 | villanueva
# Processing Record 15 of Set 7 | calbuco
# Processing Record 16 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 17 of Set 7 | kavieng
# Processing Record 18 of Set 7 | san policarpo
# Processing Record 19 of Set 7 | kahului
# Processing Record 20 of Set 7 | luebo
# Processing Record 21 of Set 7 | north platte
# Processing Record 22 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 7 | korla
# Processing Record 24 of Set 7 | mehamn
# Processing Record 25 of Set 7 | walvis bay
# Processing Record 26 of Set 7 | inuvik
# Processing Record 27 of Set 7 | manthani
# Processing Record 28 of Set 7 | severnyy
# Processing Record 29 of Set 7 | jieshou
# Processing Record 30 of Set 7 | pisco
# Processing Record 31 of Set 7 | beringovskiy
# Processing Record 32 of Set 7 | paita
# Processing Record 33 of Set 7 | salinas
# Processing Record 34 of Set 7 | luderitz
# Processing Record 35 of Set 7 | brenham
# Processing Record 36 of Set 7 | la paz
# Processing Record 37 of Set 7 | omboue
# Processing Record 38 of Set 7 | georgetown
# Processing Record 39 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 7 | montepuez
# Processing Record 41 of Set 7 | jalu
# Processing Record 42 of Set 7 | innisfail
# Processing Record 43 of Set 7 | novyy urgal
# Processing Record 44 of Set 7 | sakakah
# Processing Record 45 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 46 of Set 7 | yumen
# Processing Record 47 of Set 7 | toro
# Processing Record 48 of Set 7 | arak
# Processing Record 49 of Set 7 | maningrida
# Processing Record 50 of Set 7 | carnarvon
# Processing Record 1 of Set 8 | pizarro
# Processing Record 2 of Set 8 | san cristobal
# Processing Record 3 of Set 8 | hengshui
# Processing Record 4 of Set 8 | saint-augustin
# Processing Record 5 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 8 | fort smith
# Processing Record 7 of Set 8 | novikovo
# Processing Record 8 of Set 8 | musiri
# Processing Record 9 of Set 8 | zamhlay
# City not found. Skipping...
# Processing Record 10 of Set 8 | comoapan
# Processing Record 11 of Set 8 | lagoa
# Processing Record 12 of Set 8 | santa isabel do rio negro
# Processing Record 13 of Set 8 | suntar
# Processing Record 14 of Set 8 | warrnambool
# Processing Record 15 of Set 8 | sao joao da barra
# Processing Record 16 of Set 8 | pishin
# Processing Record 17 of Set 8 | minuri
# Processing Record 18 of Set 8 | murdochville
# Processing Record 19 of Set 8 | ust-uda
# Processing Record 20 of Set 8 | bodden town
# Processing Record 21 of Set 8 | beloha
# Processing Record 22 of Set 8 | sharan
# Processing Record 23 of Set 8 | fortuna
# Processing Record 24 of Set 8 | tripoli
# Processing Record 25 of Set 8 | nagpur
# Processing Record 26 of Set 8 | artsyz
# Processing Record 27 of Set 8 | ilulissat
# Processing Record 28 of Set 8 | nago
# Processing Record 29 of Set 8 | comodoro rivadavia
# Processing Record 30 of Set 8 | la ronge
# Processing Record 31 of Set 8 | chicama
# Processing Record 32 of Set 8 | borogontsy
# Processing Record 33 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | kizhinga
# Processing Record 35 of Set 8 | kavaratti
# Processing Record 36 of Set 8 | kindu
# Processing Record 37 of Set 8 | lompoc
# Processing Record 38 of Set 8 | taoudenni
# Processing Record 39 of Set 8 | kruisfontein
# Processing Record 40 of Set 8 | sorland
# Processing Record 41 of Set 8 | kapuskasing
# Processing Record 42 of Set 8 | koslan
# Processing Record 43 of Set 8 | canon city
# Processing Record 44 of Set 8 | teguldet
# Processing Record 45 of Set 8 | gambela
# Processing Record 46 of Set 8 | tacuati
# Processing Record 47 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 8 | ferrol
# Processing Record 49 of Set 8 | tananger
# Processing Record 50 of Set 8 | bosaso
# Processing Record 1 of Set 9 | jumla
# Processing Record 2 of Set 9 | taman
# Processing Record 3 of Set 9 | tzucacab
# Processing Record 4 of Set 9 | kaili
# Processing Record 5 of Set 9 | yueyang
# Processing Record 6 of Set 9 | tolaga bay
# Processing Record 7 of Set 9 | baruun-urt
# Processing Record 8 of Set 9 | mana
# Processing Record 9 of Set 9 | bogale
# Processing Record 10 of Set 9 | sabancuy
# Processing Record 11 of Set 9 | okhotsk
# Processing Record 12 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 13 of Set 9 | nishihara
# Processing Record 14 of Set 9 | kisesa
# Processing Record 15 of Set 9 | itoman
# Processing Record 16 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 9 | oranjemund
# Processing Record 18 of Set 9 | guhagar
# Processing Record 19 of Set 9 | sur
# Processing Record 20 of Set 9 | pundaguitan
# Processing Record 21 of Set 9 | coihaique
# Processing Record 22 of Set 9 | hit
# Processing Record 23 of Set 9 | chumikan
# Processing Record 24 of Set 9 | khokhlovo
# Processing Record 25 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 9 | bronnoysund
# Processing Record 27 of Set 9 | cabinda
# Processing Record 28 of Set 9 | stony mountain
# Processing Record 29 of Set 9 | shelby
# Processing Record 30 of Set 9 | nyurba
# Processing Record 31 of Set 9 | beruwala
# Processing Record 32 of Set 9 | henties bay
# Processing Record 33 of Set 9 | nicoya
# Processing Record 34 of Set 9 | abengourou
# Processing Record 35 of Set 9 | quelimane
# Processing Record 36 of Set 9 | rio gallegos
# Processing Record 37 of Set 9 | iqaluit
# Processing Record 38 of Set 9 | ust-tsilma
# Processing Record 39 of Set 9 | manakara
# Processing Record 40 of Set 9 | estelle
# Processing Record 41 of Set 9 | lorengau
# Processing Record 42 of Set 9 | husavik
# Processing Record 43 of Set 9 | virginia beach
# Processing Record 44 of Set 9 | ishigaki
# Processing Record 45 of Set 9 | praia da vitoria
# Processing Record 46 of Set 9 | changji
# Processing Record 47 of Set 9 | jibuti
# Processing Record 48 of Set 9 | chimbote
# Processing Record 49 of Set 9 | sibolga
# Processing Record 50 of Set 9 | mucurapo
# Processing Record 1 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 10 | broome
# Processing Record 3 of Set 10 | podbelsk
# City not found. Skipping...
# Processing Record 4 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 10 | san miguel el alto
# Processing Record 6 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 7 of Set 10 | ust-maya
# Processing Record 8 of Set 10 | mogok
# Processing Record 9 of Set 10 | soto la marina
# Processing Record 10 of Set 10 | kaabong
# Processing Record 11 of Set 10 | neryungri
# Processing Record 12 of Set 10 | pestretsy
# Processing Record 13 of Set 10 | rezh
# Processing Record 14 of Set 10 | palmer
# Processing Record 15 of Set 10 | bay-khaak
# Processing Record 16 of Set 10 | savannah bight
# Processing Record 17 of Set 10 | kropotkin
# Processing Record 18 of Set 10 | myrtle beach
# Processing Record 19 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 10 | surgut
# Processing Record 21 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 22 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 23 of Set 10 | kharan
# Processing Record 24 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 25 of Set 10 | wuwei
# Processing Record 26 of Set 10 | golden
# Processing Record 27 of Set 10 | maarianhamina
# Processing Record 28 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 10 | sao jose da coroa grande
# Processing Record 30 of Set 10 | barabai
# Processing Record 31 of Set 10 | aljezur
# Processing Record 32 of Set 10 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 10 | kieta
# Processing Record 34 of Set 10 | yabrud
# Processing Record 35 of Set 10 | hobyo
# Processing Record 36 of Set 10 | quincy
# Processing Record 37 of Set 10 | natchitoches
# Processing Record 38 of Set 10 | le passage
# Processing Record 39 of Set 10 | loukhi
# Processing Record 40 of Set 10 | bilibino
# Processing Record 41 of Set 10 | itinga
# Processing Record 42 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of Set 10 | mamu kanjan
# Processing Record 44 of Set 10 | ryotsu
# Processing Record 45 of Set 10 | cap malheureux
# Processing Record 46 of Set 10 | marquette
# Processing Record 47 of Set 10 | alamosa
# Processing Record 48 of Set 10 | tura
# Processing Record 49 of Set 10 | bila krynytsya
# Processing Record 50 of Set 10 | hede
# Processing Record 1 of Set 11 | trairi
# Processing Record 2 of Set 11 | bay roberts
# Processing Record 3 of Set 11 | fuxin
# Processing Record 4 of Set 11 | ongole
# Processing Record 5 of Set 11 | zatoka
# Processing Record 6 of Set 11 | port-cartier
# Processing Record 7 of Set 11 | byron bay
# Processing Record 8 of Set 11 | qui nhon
# Processing Record 9 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 11 | mount gambier
# Processing Record 11 of Set 11 | adre
# Processing Record 12 of Set 11 | dongli
# Processing Record 13 of Set 11 | arica
# Processing Record 14 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 15 of Set 11 | ostersund
# Processing Record 16 of Set 11 | olinda
# Processing Record 17 of Set 11 | ransang
# Processing Record 18 of Set 11 | katha
# City not found. Skipping...
# Processing Record 19 of Set 11 | pangnirtung
# Processing Record 20 of Set 11 | tomatlan
# Processing Record 21 of Set 11 | acapulco
# Processing Record 22 of Set 11 | mantua
# Processing Record 23 of Set 11 | carbonia
# Processing Record 24 of Set 11 | moron
# Processing Record 25 of Set 11 | methoni
# Processing Record 26 of Set 11 | porto santo
# Processing Record 27 of Set 11 | skelleftea
# Processing Record 28 of Set 11 | abalak
# Processing Record 29 of Set 11 | cap-aux-meules
# Processing Record 30 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 11 | tevriz
# Processing Record 32 of Set 11 | katangli
# Processing Record 33 of Set 11 | phalaborwa
# Processing Record 34 of Set 11 | cabildo
# Processing Record 35 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 36 of Set 11 | ust-barguzin
# Processing Record 37 of Set 11 | maunabo
# Processing Record 38 of Set 11 | qandala
# Processing Record 39 of Set 11 | hurghada
# Processing Record 40 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 11 | huambo
# Processing Record 42 of Set 11 | chifeng
# Processing Record 43 of Set 11 | gospic
# Processing Record 44 of Set 11 | doctor arroyo
# Processing Record 45 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 11 | hirtshals
# Processing Record 47 of Set 11 | duz
# City not found. Skipping...
# Processing Record 48 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 49 of Set 11 | matay
# Processing Record 50 of Set 11 | tulum
# Processing Record 1 of Set 12 | staraya russa
# Processing Record 2 of Set 12 | roy
# Processing Record 3 of Set 12 | codrington
# Processing Record 4 of Set 12 | bristol
# Processing Record 5 of Set 12 | mafra
# Processing Record 6 of Set 12 | riachao
# Processing Record 7 of Set 12 | nhulunbuy
# Processing Record 8 of Set 12 | tukrah
# Processing Record 9 of Set 12 | ozu
# Processing Record 10 of Set 12 | pocone
# Processing Record 11 of Set 12 | vredendal
# Processing Record 12 of Set 12 | carutapera
# Processing Record 13 of Set 12 | mandurah
# Processing Record 14 of Set 12 | biak
# Processing Record 15 of Set 12 | baghmara
# Processing Record 16 of Set 12 | naushki
# Processing Record 17 of Set 12 | methven
# Processing Record 18 of Set 12 | kulu
# Processing Record 19 of Set 12 | pasighat
# Processing Record 20 of Set 12 | tabou
# Processing Record 21 of Set 12 | onalaska
# Processing Record 22 of Set 12 | los llanos de aridane
# Processing Record 23 of Set 12 | mackenzie
# Processing Record 24 of Set 12 | abnub
# Processing Record 25 of Set 12 | constitucion
# Processing Record 26 of Set 12 | rocha
# Processing Record 27 of Set 12 | banfora
# Processing Record 28 of Set 12 | atocha
# Processing Record 29 of Set 12 | pochutla
# Processing Record 30 of Set 12 | chipinge
# Processing Record 31 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 12 | vostok
# Processing Record 33 of Set 12 | camabatela
# Processing Record 34 of Set 12 | port keats
# Processing Record 35 of Set 12 | halifax
# Processing Record 36 of Set 12 | andilamena
# Processing Record 37 of Set 12 | wukari
# Processing Record 38 of Set 12 | hermsdorf
# Processing Record 39 of Set 12 | gunjur
# Processing Record 40 of Set 12 | haines junction
# Processing Record 41 of Set 12 | denpasar
# Processing Record 42 of Set 12 | norman
# Processing Record 43 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 12 | hambantota
# Processing Record 45 of Set 12 | opuwo
# Processing Record 46 of Set 12 | inhambane
# Processing Record 47 of Set 12 | caronport
# Processing Record 48 of Set 12 | oranjestad
# Processing Record 49 of Set 12 | spearfish
# Processing Record 50 of Set 12 | dongsheng
# Processing Record 1 of Set 13 | dotnuva
# Processing Record 2 of Set 13 | kungurtug
# Processing Record 3 of Set 13 | ibotirama
# Processing Record 4 of Set 13 | santa maria
# Processing Record 5 of Set 13 | kangaatsiaq
# Processing Record 6 of Set 13 | dicabisagan
# Processing Record 7 of Set 13 | flin flon
# Processing Record 8 of Set 13 | kargil
# Processing Record 9 of Set 13 | bullhead city
# Processing Record 10 of Set 13 | muzhi
# Processing Record 11 of Set 13 | grindavik
# Processing Record 12 of Set 13 | vrangel
# Processing Record 13 of Set 13 | lenoir
# Processing Record 14 of Set 13 | belmonte
# Processing Record 15 of Set 13 | khani
# Processing Record 16 of Set 13 | shaoguan
# Processing Record 17 of Set 13 | dzaoudzi
# Processing Record 18 of Set 13 | dawson creek
# Processing Record 19 of Set 13 | mahajanga
# Processing Record 20 of Set 13 | straumen
# Processing Record 21 of Set 13 | sinnamary
# Processing Record 22 of Set 13 | christchurch
# Processing Record 23 of Set 13 | edd
# Processing Record 24 of Set 13 | libreville
# Processing Record 25 of Set 13 | srednekolymsk
# Processing Record 26 of Set 13 | bubaque
# Processing Record 27 of Set 13 | akyab
# Processing Record 28 of Set 13 | yefira
# City not found. Skipping...
# Processing Record 29 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 13 | yerbogachen
# Processing Record 31 of Set 13 | chalisgaon
# Processing Record 32 of Set 13 | berdigestyakh
# Processing Record 33 of Set 13 | ewa beach
# Processing Record 34 of Set 13 | tashtagol
# Processing Record 35 of Set 13 | puksoozero
# Processing Record 36 of Set 13 | faya
# Processing Record 37 of Set 13 | aktau
# Processing Record 38 of Set 13 | paracuru
# Processing Record 39 of Set 13 | mayo
# Processing Record 40 of Set 13 | bahia blanca
# Processing Record 41 of Set 13 | barentu
# Processing Record 42 of Set 13 | kaspiysk
# Processing Record 43 of Set 13 | sungurlu
# Processing Record 44 of Set 13 | maragogi
# Processing Record 45 of Set 13 | geraldton
# Processing Record 46 of Set 13 | lithakia
# Processing Record 47 of Set 13 | taganak
# Processing Record 48 of Set 13 | tonosho
# Processing Record 49 of Set 13 | bonaventure
# Processing Record 50 of Set 13 | alice springs
# Processing Record 1 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 14 | tilichiki
# Processing Record 3 of Set 14 | kolda
# Processing Record 4 of Set 14 | sibi
# Processing Record 5 of Set 14 | awbari
# Processing Record 6 of Set 14 | mangit
# Processing Record 7 of Set 14 | anito
# Processing Record 8 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 14 | eucaliptus
# Processing Record 10 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 11 of Set 14 | kerema
# Processing Record 12 of Set 14 | ugoofaaru
# Processing Record 13 of Set 14 | mityana
# Processing Record 14 of Set 14 | high level
# Processing Record 15 of Set 14 | lazaro cardenas
# Processing Record 16 of Set 14 | kapit
# Processing Record 17 of Set 14 | celestun
# Processing Record 18 of Set 14 | solnechnyy
# Processing Record 19 of Set 14 | labuhan
# Processing Record 20 of Set 14 | buala
# Processing Record 21 of Set 14 | akdepe
# Processing Record 22 of Set 14 | changli
# Processing Record 23 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 24 of Set 14 | foxton
# Processing Record 25 of Set 14 | paamiut
# Processing Record 26 of Set 14 | dwarka
# Processing Record 27 of Set 14 | jamame
# Processing Record 28 of Set 14 | sachin
# Processing Record 29 of Set 14 | concordia
# Processing Record 30 of Set 14 | itaituba
# Processing Record 31 of Set 14 | takaka
# Processing Record 32 of Set 14 | florissant
# Processing Record 33 of Set 14 | batagay-alyta
# Processing Record 34 of Set 14 | sambava
# Processing Record 35 of Set 14 | nizwa
# Processing Record 36 of Set 14 | hwange
# Processing Record 37 of Set 14 | alofi
# Processing Record 38 of Set 14 | weiser
# Processing Record 39 of Set 14 | gamba
# Processing Record 40 of Set 14 | mukhen
# Processing Record 41 of Set 14 | campo alegre
# Processing Record 42 of Set 14 | jamsa
# Processing Record 43 of Set 14 | buraydah
# Processing Record 44 of Set 14 | biltine
# Processing Record 45 of Set 14 | eirunepe
# Processing Record 46 of Set 14 | silago
# Processing Record 47 of Set 14 | zeya
# Processing Record 48 of Set 14 | lae
# Processing Record 49 of Set 14 | khipro
# Processing Record 50 of Set 14 | aykhal
# Processing Record 1 of Set 15 | anadyr
# Processing Record 2 of Set 15 | laguna
# Processing Record 3 of Set 15 | shenjiamen
# Processing Record 4 of Set 15 | gurun
# Processing Record 5 of Set 15 | tanhacu
# Processing Record 6 of Set 15 | amos
# Processing Record 7 of Set 15 | bonavista
# Processing Record 8 of Set 15 | chornukhy
# Processing Record 9 of Set 15 | la union
# Processing Record 10 of Set 15 | anzio
# Processing Record 11 of Set 15 | waddan
# Processing Record 12 of Set 15 | kyzyl-suu
# Processing Record 13 of Set 15 | ndungu
# Processing Record 14 of Set 15 | fairbanks
# Processing Record 15 of Set 15 | manama
# Processing Record 16 of Set 15 | kumluca
# Processing Record 17 of Set 15 | sogdiondon
# City not found. Skipping...
# Processing Record 18 of Set 15 | pachelma
# Processing Record 19 of Set 15 | westport
# Processing Record 20 of Set 15 | daultala
# Processing Record 21 of Set 15 | severnoye
# Processing Record 22 of Set 15 | monrovia
# Processing Record 23 of Set 15 | dudinka
# Processing Record 24 of Set 15 | samut sakhon
# Processing Record 25 of Set 15 | daru
# Processing Record 26 of Set 15 | abadan
# Processing Record 27 of Set 15 | santa fe
# Processing Record 28 of Set 15 | samdrup jongkhar
# Processing Record 29 of Set 15 | avera
# Processing Record 30 of Set 15 | chelno-vershiny
# Processing Record 31 of Set 15 | nixa
# Processing Record 32 of Set 15 | dauphin
# Processing Record 33 of Set 15 | tarpon springs
# Processing Record 34 of Set 15 | salalah
# Processing Record 35 of Set 15 | cintalapa
# Processing Record 36 of Set 15 | ilo
# Processing Record 37 of Set 15 | la asuncion
# Processing Record 38 of Set 15 | huilong
# Processing Record 39 of Set 15 | krasnoselkup
# Processing Record 40 of Set 15 | yenagoa
# Processing Record 41 of Set 15 | sandwick
# Processing Record 42 of Set 15 | pangai
# Processing Record 43 of Set 15 | meulaboh
# Processing Record 44 of Set 15 | kaka
# Processing Record 45 of Set 15 | diffa
# Processing Record 46 of Set 15 | erenhot
# Processing Record 47 of Set 15 | asfi
# Processing Record 48 of Set 15 | edson
# Processing Record 49 of Set 15 | yakshur-bodya
# City not found. Skipping...
# Processing Record 50 of Set 15 | skagen
# Processing Record 1 of Set 16 | russell
# Processing Record 2 of Set 16 | lander
# Processing Record 3 of Set 16 | kommunar
# Processing Record 4 of Set 16 | barcelona
# Processing Record 5 of Set 16 | loandjili
# Processing Record 6 of Set 16 | lakes entrance
# Processing Record 7 of Set 16 | floriano
# Processing Record 8 of Set 16 | taitung
# Processing Record 9 of Set 16 | deulgaon raja
# Processing Record 10 of Set 16 | tungkang
# City not found. Skipping...
# Processing Record 11 of Set 16 | puerto colombia
# Processing Record 12 of Set 16 | camopi
# Processing Record 13 of Set 16 | port blair
# Processing Record 14 of Set 16 | veraval
# Processing Record 15 of Set 16 | shibarghan
# City not found. Skipping...
# Processing Record 16 of Set 16 | areosa
# Processing Record 17 of Set 16 | ribas do rio pardo
# Processing Record 18 of Set 16 | mizdah
# Processing Record 19 of Set 16 | mao
# Processing Record 20 of Set 16 | uruzgan
# Processing Record 21 of Set 16 | lokosovo
# Processing Record 22 of Set 16 | maghama
# City not found. Skipping...
# Processing Record 23 of Set 16 | linxia
# Processing Record 24 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 16 | velingara
# Processing Record 26 of Set 16 | luena
# Processing Record 27 of Set 16 | san pedro
# Processing Record 28 of Set 16 | mercedes
# Processing Record 29 of Set 16 | genhe
# Processing Record 30 of Set 16 | buritis
# Processing Record 31 of Set 16 | manavalakurichi
# Processing Record 32 of Set 16 | bengkulu
# Processing Record 33 of Set 16 | port macquarie
# Processing Record 34 of Set 16 | san lawrenz
# Processing Record 35 of Set 16 | roanoke rapids
# Processing Record 36 of Set 16 | jimma
# Processing Record 37 of Set 16 | vorobyevka
# Processing Record 38 of Set 16 | amapa
# Processing Record 39 of Set 16 | araouane
# Processing Record 40 of Set 16 | kauhajoki
# Processing Record 41 of Set 16 | zhangye
# Processing Record 42 of Set 16 | flinders
# Processing Record 43 of Set 16 | barra do garcas
# Processing Record 44 of Set 16 | pevek
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 723

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus      ZA -34.4187   19.2345     72.81        81           2
# 1       Ushuaia      AR -54.8000  -68.3000     49.66        46          20
# 2       Rikitea      PF -23.1203 -134.9692     79.57        75           4
# 3        Bulgan      MN  48.8125  103.5347     12.07        76          38
# 4        Yulara      AU -25.2406  130.9889     80.44        24          17
# 5     Busselton      AU -33.6500  115.3333     63.93        62         100
# 6        Albany      US  42.6001  -73.9662     59.67        83         100
# 7    Chokurdakh      RU  70.6333  147.9167    -21.39       100          89
# 8     Ulladulla      AU -35.3500  150.4667     61.70        87          56
# 9  Komsomolskiy      UZ  40.4272   71.7189     39.92        75          75
#
#    Wind Speed Current Description
# 0       14.34           clear sky
# 1        6.91          few clouds
# 2        8.88          light rain
# 3        3.47    scattered clouds
# 4       11.50          few clouds
# 5       12.75          light rain
# 6        3.00     overcast clouds
# 7        4.94     overcast clouds
# 8        5.21       broken clouds
# 9        4.61          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
